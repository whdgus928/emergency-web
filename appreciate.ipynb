# %%
import requests
import pprint
import json
import pandas as pd

url = 'http://apis.data.go.kr/1741000/NSIService/getFcltsCheckResultInfoSearch'
params ={'serviceKey' : '3ouN4EKp4qGz+V76EbDHKehnbp5sYL0o19tpl5fAl2Q7s4ZosClGRfc1ENwk+2Px4QUPi4gCuCHGuG3kXFrs9w==',
        'pageNo' : '1',
        'numOfRows' : '10',
        'resultType' : 'json',
        'check_year' : '2020',
        'fclts_nm' : '어린이집',
        'ldong_addr_mgpl_dg_cd' : '41',
        'ldong_addr_mgpl_sggu_cd' : '41195',
        'ldong_addr_mgpl_sggu_emd_cd' : '41195000',
        'last_modf_dt' : '20200101' }

response = requests.get(url, params=params)
contents = response.text
# pp = pprint.PrettyPrinter(indent =4)
# pp.pprint(response.content)

json_ob = json.loads(contents)
body = json_ob['response']['body']['item']
body = pd.json_normalize(body)

# %%
body
# Out:
#   ifCudFlag  safeFcltsMngNo chckRsltSn fllwManagtCd fllwManagtNm safeClCd  \
# 0         I  13200000061815          1                            0210408
# 1         I  13200000061816          1                            0210408
# 2         I  13200000061817          1                            0210408
# 3         I  13200000061830          1                            0210408
# 4         I  13200000061831          1                            0210408
#
#   chckTrgTyNm jrsdRelmNm       fcltsNm eqpNm  ... chckEndDe pntmtrCn  \
# 0     어린이보호구역       교통시설  도당동 근로복지어린이집        ...  20200623
# 1     어린이보호구역       교통시설       새중동어린이집        ...  20200623
# 2     어린이보호구역       교통시설      숙명키즈어린이집        ...  20200623
# 3     어린이보호구역       교통시설        재원어린이집        ...  20200623
# 4     어린이보호구역       교통시설       큰나무어린이집        ...  20200623
#
#   fllwManagtCn chckYear fllwManagtSttusCd fllwManagtSttusNm  \
# 0                  2020                                점검완료
# 1                  2020                                점검완료
# 2                  2020                                점검완료
# 3                  2020                                점검완료
# 4                  2020                                점검완료
#
#           fctlsAdres          latitude         longitude           lastModfDt
# 0     경기도 부천시 도당동 46  37.5181605781145  126.787657417824  2020-12-02 11:43:59
# 1   경기도 부천시 중동 710-4  37.4949657198562  126.765566874769  2020-12-02 11:43:59
# 2  경기도 부천시 역곡동 103-6  37.4904239563354  126.811091827007  2020-12-02 11:43:59
# 3  경기도 부천시 역곡동 115-1  37.4885188473775  126.814432931513  2020-12-02 11:43:59
# 4  경기도 부천시 약대동 47-16  37.5140631887315  126.768066731182  2020-12-02 11:43:59
#
# [5 rows x 23 columns]

# %%
# 시도코드
{'서울특별시': 11,'부산광역시': 21,
 '대구광역시': 22,'인천광역시': 23,
 '광주광역시': 24,'대전광역시': 25,
 '울산광역시': 26,'세종특별자치시': 29,
 '경기도': 31,'강원도': 32,'충청북도': 33,
 '충청남도': 34,'전라북도': 35,'전라남도': 36,
 '경상북도': 37,'경상남도': 38,'제주특별자치도': 39}
# Out:
# {'서울특별시': 11,
#  '부산광역시': 21,
#  '대구광역시': 22,
#  '인천광역시': 23,
#  '광주광역시': 24,
#  '대전광역시': 25,
#  '울산광역시': 26,
#  '세종특별자치시': 29,
#  '경기도': 31,
#  '강원도': 32,
#  '충청북도': 33,
#  '충청남도': 34,
#  '전라북도': 35,
#  '전라남도': 36,
#  '경상북도': 37,
#  '경상남도': 38,
#  '제주특별자치도': 39}

# %% [markdown]
# # 이재민 임시주거시설 정보 데이터 만들기

# %%
import requests
import pprint
import json
import pandas as pd
vin_df = pd.DataFrame()
pageNo = 1
while pageNo <= 16:
        pageNo = str(pageNo)
        url = 'http://apis.data.go.kr/1741000/TemporaryHousingFacilityVictim3/getTemporaryHousingFacilityVictim1List'
        params ={'serviceKey' : '3ouN4EKp4qGz+V76EbDHKehnbp5sYL0o19tpl5fAl2Q7s4ZosClGRfc1ENwk+2Px4QUPi4gCuCHGuG3kXFrs9w==',
                'pageNo' : pageNo,
                'numOfRows' : '1000',
                'type' : 'json' }

        response = requests.get(url, params=params)
        contents = response.text
        json_ob = json.loads(contents)
        body = json_ob['TemporaryHousingFacilityVictim'][1]['row']
        body = pd.json_normalize(body)
        vin_df = pd.concat([vin_df,body], axis = 0)
        pageNo = int(pageNo) + 1
        
columns = ['ctprvn_nm', 'sgg_nm', 'acmdfclty_se_nm', 'vt_acmdfclty_nm', 'dtl_adres', 'fclty_ar', 'vt_acmd_psbl_nmpr', 'mngps_nm', 'mngps_telno', 'xcord', 'ycord']
vin_df2 = vin_df[columns]
vin_df2.columns = ['시도명', '시군구명', '시설구분', '시설명', '상세주소','시설면적', '주거능력','관리부서','지자체담당자연락처', '경도', '위도']
vin_df2.reset_index(drop = True).to_csv('C:/pythonproject/streamlit/using_data/이재민 임시주거시설 정보.csv', index = False, encoding = 'utf-8-sig')
# json_ob = json.loads(contents)
# body = json_ob['response']['body']['item']
# body = pd.json_normalize(body)

# %% [markdown]
# # 구호물자

# %%
df = pd.read_csv("C:/pythonproject/streamlit/using_data/행정안전부_재해구호물자 정보_04_30_2020.csv", encoding = 'cp949')

# %%
df['시도명'] = df['주소'].str.split(' ').str[0]
df['시군구명'] = df['주소'].str.split(' ').str[1]

# %%
df.to_csv('C:/pythonproject/streamlit/using_data/구호물자정보.csv', index = False, encoding = 'utf-8-sig')

# %% [markdown]
# # 주민대피시설 및 대피가능 인구 통계 정보

# %%
import requests
import pprint
import json
import pandas as pd
url = 'http://apis.data.go.kr/1741000/ResidentEvacuateYearAfter2017'
params ={'serviceKey' : '3ouN4EKp4qGz+V76EbDHKehnbp5sYL0o19tpl5fAl2Q7s4ZosClGRfc1ENwk+2Px4QUPi4gCuCHGuG3kXFrs9w==',
        'pageNo' : '1',
        'numOfRows' : '10'}
response = requests.get(url, params=params)
content = response.text

# %%
pp = pprint.PrettyPrinter(indent = 4)

# %%
pp.pprint(content)
# Out:
# ('<?xml version="1.0" encoding="UTF-8"?>\n'
#  '<soapenv:Envelope '
#  'xmlns:soapenv="http://schemas.xmlsoap.org/soap/envelope/">\n'
#  '    <soapenv:Body>\n'
#  '        <soapenv:Fault>\n'
#  '            <faultcode>soapenv:Server</faultcode>\n'
#  '            <faultstring>Policy Falsified</faultstring>\n'
#  '            '
#  '<faultactor>http://apis.data.go.kr/1741000/ResidentEvacuateYearAfter2017?serviceKey=3ouN4EKp4qGz%2BV76EbDHKehnbp5sYL0o19tpl5fAl2Q7s4ZosClGRfc1ENwk%2B2Px4QUPi4gCuCHGuG3kXFrs9w%3D%3D&amp;pageNo=1&amp;numOfRows=10</faultactor>\n'
#  '            <detail>\n'
#  '                <l7:policyResult\n'
#  '                    status="Service Not Found.  The request may have been '
#  'sent to an invalid URL, or intended for an unsupported operation." '
#  'xmlns:l7="http://www.layer7tech.com/ws/policy/fault"/>\n'
#  '            </detail>\n'
#  '        </soapenv:Fault>\n'
#  '    </soapenv:Body>\n'
#  '</soapenv:Envelope>\n')

# %%
from PIL import Image
def load_image(image_file):
    img = Image.open(image_file)
    return img
load_image('C:/Users/82106/Documents/PythonProject/streamlit/LDM_11620/LDM_11620.img')
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# c:\Users\82106\Documents\PythonProject\streamlit\appreciate.ipynb 셀 14 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/82106/Documents/PythonProject/streamlit/appreciate.ipynb#X16sZmlsZQ%3D%3D?line=2'>3</a>     img = Image.open(image_file)
#       <a href='vscode-notebook-cell:/c%3A/Users/82106/Documents/PythonProject/streamlit/appreciate.ipynb#X16sZmlsZQ%3D%3D?line=3'>4</a>     return img
# ----> <a href='vscode-notebook-cell:/c%3A/Users/82106/Documents/PythonProject/streamlit/appreciate.ipynb#X16sZmlsZQ%3D%3D?line=4'>5</a> load_image('C:/Users/82106/Documents/PythonProject/streamlit/LDM_11620/LDM_11620.img')
#
# c:\Users\82106\Documents\PythonProject\streamlit\appreciate.ipynb 셀 14 in load_image(image_file)
#       <a href='vscode-notebook-cell:/c%3A/Users/82106/Documents/PythonProject/streamlit/appreciate.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a> def load_image(image_file):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/82106/Documents/PythonProject/streamlit/appreciate.ipynb#X16sZmlsZQ%3D%3D?line=2'>3</a>     img = Image.open(image_file)
#       <a href='vscode-notebook-cell:/c%3A/Users/82106/Documents/PythonProject/streamlit/appreciate.ipynb#X16sZmlsZQ%3D%3D?line=3'>4</a>     return img
#
# File c:\Users\82106\AppData\Local\Programs\Python\Python38\lib\site-packages\PIL\Image.py:3123, in open(fp, mode, formats)
#    3121 for message in accept_warnings:
#    3122     warnings.warn(message)
# -> 3123 raise UnidentifiedImageError(
#    3124     "cannot identify image file %r" % (filename if filename else fp)
#    3125 )
#
# UnidentifiedImageError: cannot identify image file 'C:/Users/82106/Documents/PythonProject/streamlit/LDM_11620/LDM_11620.img'

# %%
# Out:
# ('<?xml version="1.0" encoding="UTF-8" '
#  'standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL '
#  'SERVICE.</resultMsg></header><body><items><item><dutyName>연세대학교의과대학강남세브란스병원</dutyName><dutyTel3>02-2019-3333</dutyTel3><hpid>A1100015</hpid><hv1>0</hv1><hv10>Y</hv10><hv11>Y</hv11><hv12>0</hv12><hv13>0</hv13><hv14>0</hv14><hv15>0</hv15><hv16>0</hv16><hv17>0</hv17><hv18>0</hv18><hv19>0</hv19><hv2>0</hv2><hv21>0</hv21><hv22>0</hv22><hv23>0</hv23><hv24>0</hv24><hv25>0</hv25><hv26>0</hv26><hv27>0</hv27><hv3>0</hv3><hv4>0</hv4><hv5>Y</hv5><hv6>0</hv6><hv7>Y</hv7><hv8>0</hv8><hv9>0</hv9><hvamyn>Y</hvamyn><hvangioayn>N</hvangioayn><hvcc>0</hvcc><hvccc>0</hvccc><hvctayn>Y</hvctayn><hvec>-23</hvec><hvgc>46</hvgc><hvicc>4</hvicc><hvidate>20221216135937</hvidate><hvmriayn>Y</hvmriayn><hvncc>5</hvncc><hvoc>0</hvoc><hvventiayn>Y</hvventiayn><phpid>A1100015</phpid><rnum>1</rnum></item><item><dutyName>삼성서울병원</dutyName><dutyTel3>02-3410-2060</dutyTel3><hpid>A1100010</hpid><hv1>0</hv1><hv10>Y</hv10><hv11>Y</hv11><hv12>0</hv12><hv13>0</hv13><hv14>0</hv14><hv15>0</hv15><hv16>0</hv16><hv17>0</hv17><hv18>0</hv18><hv19>0</hv19><hv2>9</hv2><hv21>0</hv21><hv22>0</hv22><hv23>0</hv23><hv24>0</hv24><hv25>0</hv25><hv26>0</hv26><hv27>0</hv27><hv3>8</hv3><hv4>0</hv4><hv5>Y</hv5><hv6>4</hv6><hv7>Y</hv7><hv8>0</hv8><hv9>0</hv9><hvamyn>Y</hvamyn><hvangioayn>N</hvangioayn><hvcc>0</hvcc><hvccc>0</hvccc><hvctayn>Y</hvctayn><hvec>-14</hvec><hvgc>268</hvgc><hvicc>3</hvicc><hvidate>20221216140130</hvidate><hvmriayn>Y</hvmriayn><hvncc>4</hvncc><hvoc>16</hvoc><hvventiayn>Y</hvventiayn><phpid>A1100010</phpid><rnum>2</rnum></item></items><numOfRows>10</numOfRows><pageNo>1</pageNo><totalCount>2</totalCount></body></response>')
# None

# %%
# Python3 샘플 코드 #

import pprint
import requests
from os import name
import xml.etree.ElementTree as et
import pandas as pd
import bs4
from lxml import html
from urllib.parse import urlencode, quote_plus, unquote

# # 깔끔한 출력 위한 코드
# pp = pprint.PrettyPrinter(indent=4)
# print(pp.pprint(content))


url = 'http://apis.data.go.kr/B552657/ErmctInfoInqireService/getEmrrmRltmUsefulSckbdInfoInqire'
params ={'serviceKey' : '3ouN4EKp4qGz+V76EbDHKehnbp5sYL0o19tpl5fAl2Q7s4ZosClGRfc1ENwk+2Px4QUPi4gCuCHGuG3kXFrs9w==', 'STAGE1' : '서울특별시', 'STAGE2' : '중랑구', 'pageNo' : '1', 'numOfRows' : '100' }

response = requests.get(url, params=params)
content = response.text

### xml을 DataFrame으로 변환하기 ###
#bs4 사용하여 item 태그 분리

xml_obj = bs4.BeautifulSoup(content,'lxml-xml')
rows = xml_obj.findAll('item')

# 각 행의 컬럼, 이름, 값을 가지는 리스트 만들기
row_list = [] # 행값
name_list = [] # 열이름값
value_list = [] #데이터값

# xml 안의 데이터 수집
for i in range(0, len(rows)):
    columns = rows[i].find_all()
    #첫째 행 데이터 수집
    for j in range(0,len(columns)):
        if i ==0:
            # 컬럼 이름 값 저장
            name_list.append(columns[j].name)
        # 컬럼의 각 데이터 값 저장
        value_list.append(columns[j].text)
    # 각 행의 value값 전체 저장
    row_list.append(value_list)
    # 데이터 리스트 값 초기화
    value_list=[]

#xml값 DataFrame으로 만들기
corona_df = pd.DataFrame(row_list, columns=name_list)
corona_df = corona_df[['hvidate','hvec','hvoc','hvgc','hvamyn','dutyName','dutyTel3']]
corona_df.columns = ['정보 업데이트 일시','응급실 가용현황', '수술실 가용현황', '입원실 가용현황', '구급차 가용여부', '기관명', '연락처']
corona_df
# Out:
#        정보 업데이트 일시 응급실 가용현황 수술실 가용현황 입원실 가용현황 구급차 가용여부               기관명  \
# 0  20221216141524        7        1       60        Y  의료법인풍산의료재단동부제일병원
# 1  20221216141507        3        2       56        Y              녹색병원
# 2  20221216141500        4        6      193        Y        서울특별시서울의료원
#
#             연락처
# 0   02-490-8880
# 1   02-490-2113
# 2  02-2276-7403

# %%
'''
hvidate : 입력일시
hvec : 응급실 가용현황
hvoc : 수술실 가용현황
hvgc : 입원실 가용현황
hvamyn : 구급차가용여부
dutyname : 기관명
hv10 : VENTI(소아)
dutytel3 : 응급실전화
'''

# %%
from urllib.request import urlopen
from urllib.parse import urlencode, unquote, quote_plus
import urllib
import requests
import json
import pandas as pd
from datetime import datetime,timedelta
import warnings
import xmltodict # 결과가 xml 형식으로 반환된다. 이것을 dict 로 바꿔주는 라이브러리다
import os

filePath, fileName = os.path.split(__file__)
data_path = os.path.join(filePath,'using_data','기상청41_단기예보 조회서비스_오픈API활용가이드_격자_위경도(20221027).xlsx')


warnings.filterwarnings('ignore')
#초단기예보조회
#초단기예보정보를 조회하기 위해 발표일자, 발표시각, 예보지점 X 좌표, 예보지점 Y 좌표의 조회 조건으로 자료구분코드, 예보값, 발표일자, 발표시각, 예보지점 X 좌표, 예보지점 Y 좌표의 정보를 조회하는 기능
serviceKey='z5tZeY7iv8p2Ib1ApuO7q//wKERNpofeMjmWiun9zefOVRmdNnZkj9DCIiZoMTf3fhj6CEToyLj94bjSGZ4q4A==' #api 키
pageNo = '1' #페이지번호
numOfRows = '100' #한 페이지 결과 수
dataType = 'json' #요청자료형식(XML/JSON) Default: XML
base_date = '20221216' #‘22년 8월 13일 발표
base_time='1300' #06시30분 발표(30분 단위)
df=pd.read_excel(data_path)
#df['T1H','RN1','SKY','UUU','VVV','REH','PTY','LGT','VEC','WSD']=0
print(df.info())
for idx in df.index:
    nx=df.loc[idx,'격자 X']
    ny=df.loc[idx,'격자 Y']
    url = 'https://apis.data.go.kr/1360000/VilageFcstInfoService_2.0/getUltraSrtFcst?serviceKey={}&pageNo={}&numOfRows={}&dataType={}&base_date={}&base_time={}&nx={}&ny={}'.format(serviceKey,pageNo,numOfRows,dataType,base_date,base_time,nx,ny)
    response = requests.get(url, verify=False)
    r_data = json.loads(response.text)
    try : 
        data = pd.DataFrame(r_data['response']['body']['items']['item'])  
    except :
        data = pd.DataFrame(r_data['response']['body']['items']['item'], index = [0])
    data.drop_duplicates(['baseDate','baseTime','category'],keep='first',inplace=True,ignore_index = True)
    for j in data.index:
        df.loc[idx,data.loc[j,'category']]=data.loc[j,'fcstValue']
    print(idx)
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\pythonproject\streamlit (2)\appreciate.ipynb Cell 18 in <cell line: 12>()
#       <a href='vscode-notebook-cell:/c%3A/pythonproject/streamlit%20%282%29/appreciate.ipynb#X24sZmlsZQ%3D%3D?line=8'>9</a> import xmltodict # 결과가 xml 형식으로 반환된다. 이것을 dict 로 바꿔주는 라이브러리다
#      <a href='vscode-notebook-cell:/c%3A/pythonproject/streamlit%20%282%29/appreciate.ipynb#X24sZmlsZQ%3D%3D?line=9'>10</a> import os
# ---> <a href='vscode-notebook-cell:/c%3A/pythonproject/streamlit%20%282%29/appreciate.ipynb#X24sZmlsZQ%3D%3D?line=11'>12</a> filePath, fileName = os.path.split(__file__)
#      <a href='vscode-notebook-cell:/c%3A/pythonproject/streamlit%20%282%29/appreciate.ipynb#X24sZmlsZQ%3D%3D?line=12'>13</a> data_path = os.path.join(filePath,'using_data','기상청41_단기예보 조회서비스_오픈API활용가이드_격자_위경도(20221027).xlsx')
#      <a href='vscode-notebook-cell:/c%3A/pythonproject/streamlit%20%282%29/appreciate.ipynb#X24sZmlsZQ%3D%3D?line=15'>16</a> warnings.filterwarnings('ignore')
#
# NameError: name '__file__' is not defined

# %% [markdown]
# # 홍수정보

# %%
import requests
import pprint
import json
import pandas as pd

def flowsiteAPI_data(serviceKey, HydroType, DataType, DocumentType):
        url = f'https://api.hrfco.go.kr/{serviceKey}/{HydroType}/{DataType}{DocumentType}'
        response = requests.get(url)
        contents = response.text
        json_ob = json.loads(contents)
        body = json_ob['content']
        body = pd.json_normalize(body)
        return body

def flowsiteAPI_livedata(serviceKey, HydroType, DataType, DocumentType):
        url = f'https://api.hrfco.go.kr/{serviceKey}/{HydroType}/{DataType}/10M{DocumentType}'
        response = requests.get(url)
        contents = response.text
        pp = pprint.PrettyPrinter(indent =4)
        # pp.pprint(response.content)
        json_ob = json.loads(contents)
        body = json_ob['content']
        # body = json_ob['response']['body']['item']
        body = pd.json_normalize(body)
        return body

def request_rainfall_info():
        serviceKey = 'A3A7BEB0-361E-4134-878C-BD8004204558'
        HydroType = 'rainfall'
        DataType = 'info'
        DocumentType = '.json'
        df = flowsiteAPI_data(serviceKey, HydroType, DataType, DocumentType)
        df['시도명'] = df['addr'].str.split(' ').str[0]
        df['시군구명'] = df['addr'].str.split(' ').str[1]
        df = df[df['lat'] != ' ']
        df['lat'] = df['lat'].apply(lambda x : int(x.split('-')[0]) + (int(x.split('-')[1]) / 60) + (int(x.split('-')[2]) / 3600) if len(x.split('-')) == 3 else x)
        df['lon'] = df['lon'].apply(lambda x : int(x.split('-')[0]) + (int(x.split('-')[1]) / 60) + (int(x.split('-')[2]) / 3600) if len(x.split('-')) == 3 else x)
        df.reset_index(drop = True, inplace = True)
        df.to_csv('강수량제원정보.csv', index = False, encoding = 'utf-8-sig')
        return df

def request_rainfall_live():
        serviceKey = 'A3A7BEB0-361E-4134-878C-BD8004204558'
        HydroType = 'rainfall'
        DataType = 'list'
        DocumentType = '.json'
        live_df = flowsiteAPI_livedata(serviceKey, HydroType, DataType, DocumentType)
        df = pd.read_csv('C:/pythonproject/streamlit (2)/pages/using_data/강수량제원정보.csv', encoding = 'utf-8-sig')
        live_df['rfobscd'] = live_df['rfobscd'].astype('int64')
        rainfall_df = pd.merge(df, live_df, on = 'rfobscd', how = 'left')
        rainfall_df[['lon','lat']] = rainfall_df[['lon','lat']].astype('float64')
        return rainfall_df

# %%
serviceKey = 'A3A7BEB0-361E-4134-878C-BD8004204558'
HydroType = 'waterlevel'
DataType = 'list'
DocumentType = '.json'
water_level_live = flowsiteAPI_livedata(serviceKey, HydroType, DataType, DocumentType)
DataType = 'info'
water_level = flowsiteAPI_data(serviceKey, HydroType, DataType, DocumentType)
water_level = water_level[water_level['attwl'] != ' ']
water_level['시도명'] = water_level['addr'].str.split(' ').str[0]
water_level['lat'] = water_level['lat'].apply(lambda x : int(x.split('-')[0]) + (int(x.split('-')[1]) / 60) + (int(x.split('-')[2]) / 3600) if len(x.split('-')) == 3 else x)
water_level['lon'] = water_level['lon'].apply(lambda x : int(x.split('-')[0]) + (int(x.split('-')[1]) / 60) + (int(x.split('-')[2]) / 3600) if len(x.split('-')) == 3 else x)
# data = pd.merge(water_level, water_level_live, on = 'wlobscd', how = 'inner')
# data = data[data['almwl'] != ' ']
# data[['attwl', 'wrnwl', 'almwl', 'srswl', 'wl']] = data[['attwl', 'wrnwl', 'almwl', 'srswl', 'wl']].astype('float64')
# data['누구'] = data.apply(lambda x : '심각 수위 단계' if x['wl'] >= x['srswl']
#                                                     else ('경보수위 단계' if x['wl'] >= x['almwl']
#                                                     else ('주의보수위 단계' if x['wl'] >= x['wrnwl']
#                                                     else ('관심수위 단계' if x['wl'] >= x['attwl'] else '정상수위 단계')))  , axis = 1)

# %%
water_level.reset_index(drop = True).to_csv('C:/pythonproject/streamlit (2)/pages/using_data/flowsiteAPI_data.csv', index = False, encoding = 'utf-8-sig')

# %%
water_level = flowsiteAPI_data(serviceKey, HydroType, DataType, DocumentType)
water_level = water_level[water_level['attwl'] != ' ']
water_level['시도명'] = water_level['addr'].str.split(' ').str[0]
water_level['lat'] = water_level['lat'].apply(lambda x : int(x.split('-')[0]) + (int(x.split('-')[1]) / 60) + (int(x.split('-')[2]) / 3600) if len(x.split('-')) == 3 else x)
water_level['lon'] = water_level['lon'].apply(lambda x : int(x.split('-')[0]) + (int(x.split('-')[1]) / 60) + (int(x.split('-')[2]) / 3600) if len(x.split('-')) == 3 else x)
water_level.to_csv('flowsiteAPI_data.csv', index = False, encoding = 'utf-8-sig')

# %%
water_level = pd.read_csv('C:/pythonproject/streamlit (2)/pages/using_data/flowsiteAPI_data.csv')
water_level['wlobscd'] = water_level['wlobscd'].astype('object')

# %%
water_level.to_csv('수위단계.csv', index = False, encoding = 'utf-8-sig')
# Out:
#      wlobscd agcnm       obsnm          addr         etcaddr         lon  \
# 0    1001602   환경부    평창군(송정교)   강원도 평창군 진부면        하진부리 송정교  128.551111
# 7    1001620   환경부    정선군(송계교)       강원도 정선군     임계면 봉산리 송계교  128.849167
# 8    1001622   환경부    정선군(혈천교)       강원도 정선군     임계면 낙천리 혈천교  128.846944
# 9    1001625   환경부    정선군(송천교)       강원도 정선군     여량면 유천리 송천교  128.718611
# 10   1001626   환경부  정선군(제1여량교)   강원도 정선군 여량면       여량리 제1여량교  128.729167
# ..       ...   ...         ...           ...             ...         ...
# 798  3101696   환경부    당진시(북창교)  충청남도 당진군 순성면       중방리 150-4  126.761389
# 802  3201690   환경부    당진시(채운교)      충청남도 당진군     당진시 우두동 채운교  126.614444
# 803  3203620   환경부    보령시(동대교)      충청남도 보령시         동대동 동대교  126.598611
# 808  3203652   환경부    보령시(노천교)      충청남도 보령시     웅천읍 노천리 노천교  126.593889
# 946  5001615   환경부    담양군(금월교)      전라남도 담양군  담양읍 학동리 금월교 하류  127.016667
#
#            lat      gdt attwl wrnwl almwl srswl   pfh fstnyn links   시도명
# 0    37.624167  511.589   8.5   9.5    12  14.9  14.9      N    []   강원도
# 7    37.494167   491.02   1.5   2.5     3   3.6  3.64      N    []   강원도
# 8    37.464722  479.382     3     4     5   6.6  6.64      N    []   강원도
# 9    37.485556  374.685   3.5   4.5     6   7.3  7.32      N    []   강원도
# 10   37.473333  369.492     4     5     6   7.8  7.78      N    []   강원도
# ..         ...      ...   ...   ...   ...   ...   ...    ...   ...   ...
# 798  36.852222    1.018   3.5   4.5   5.5   6.5            N    []  충청남도
# 802  36.905000    1.192   2.5     4     5   6.2   7.4      N    []  충청남도
# 803  36.346667    3.079   1.8   2.5   3.5   4.1  7.23      N    []  충청남도
# 808  36.231111    -.544   2.5   3.8     5     6  5.47      N    []  충청남도
# 946  35.332778    53.59   1.5     2   2.5     3  3.65      N    []  전라남도
#
# [437 rows x 16 columns]

# %%
serviceKey = 'A3A7BEB0-361E-4134-878C-BD8004204558'
HydroType = 'rainfall'
DataType = 'list'
DocumentType = '.json'
water_level_live = flowsiteAPI_livedata(serviceKey, HydroType, DataType, DocumentType)
DataType = 'info'
water_level = flowsiteAPI_data(serviceKey, HydroType, DataType, DocumentType)
# water_level = water_level[water_level['attwl'] != ' ']
water_level['시도명'] = water_level['addr'].str.split(' ').str[0]
water_level['lat'] = water_level['lat'].apply(lambda x : int(x.split('-')[0]) + (int(x.split('-')[1]) / 60) + (int(x.split('-')[2]) / 3600) if len(x.split('-')) == 3 else x)
water_level['lon'] = water_level['lon'].apply(lambda x : int(x.split('-')[0]) + (int(x.split('-')[1]) / 60) + (int(x.split('-')[2]) / 3600) if len(x.split('-')) == 3 else x)
data = pd.merge(water_level, water_level_live, on = 'rfobscd', how = 'inner')
data = data[data['agcnm'] == '환경부'].reset_index(drop = True)
# data = data[data['almwl'] != ' ']

# %%
data['시도명'].unique()
# Out:
# array(['강원도', '충청북도', '경상북도', '경기도', '서울특별시', '충청남도', '대구광역시', '경상남도',
#        '전라북도', '부산광역시', '울산광역시', '대전광역시', '세종특별자치시', '전라남도', '광주광역시',
#        '전남'], dtype=object)

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[37, 127],
    zoom_start=8
)

coords = data[['lat', 'lon']]


marker_cluster = MarkerCluster().add_to(m)

for lat, long in zip(coords['lat'], coords['lon']):
    folium.Marker([lat, long], icon = folium.Icon(color="green")).add_to(marker_cluster)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_666d3c751ce443bb33b1d2d2ffa36359 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_666d3c751ce443bb33b1d2d2ffa36359&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_666d3c751ce443bb33b1d2d2ffa36359 = L.map(
#                 &quot;map_666d3c751ce443bb33b1d2d2ffa36359&quot;,
#                 {
#                     center: [37.0, 127.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_becdc2d8eaeb37433e07d512e296b332 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_666d3c751ce443bb33b1d2d2ffa36359);
#
#
#             var marker_cluster_16eb280ac26d3262963278d6384692de = L.markerClusterGroup(
#                 {}
#             );
#             map_666d3c751ce443bb33b1d2d2ffa36359.addLayer(marker_cluster_16eb280ac26d3262963278d6384692de);
#
#
#             var marker_86243517c08ed38899440926c4f8620c = L.marker(
#                 [37.70944444444445, 128.5991666666667],
#                 {}
#             ).addTo(marker_cluster_16eb280ac26d3262963278d6384692de);
#
#
#             var icon_e0474922b8db4e29e8dfcdc203786295 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_86243517c08ed38899440926c4f8620c.setIcon(icon_e0474922b8db4e29e8dfcdc203786295);
#
#
#             var marker_ab8a20638c72444ed0720674ebf52acb = L.marker(
#                 [37.384166666666665, 128.67361111111111],
#                 {}
#             ).addTo(marker_cluster_16eb280ac26d3262963278d6384692de);
#
#
#             var icon_eca454f4f9e116f3328789f16d4a99da = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ab8a20638c72444ed0720674ebf52acb.setIcon(icon_eca454f4f9e116f3328789f16d4a99da);
#
#
#             var marker_37108b1003e7b2f7609b7e7f464cbe8f = L.marker(
#                 [37.586111111111116, 128.7775],
#                 {}
#             ).addTo(marker_cluster_16eb280ac26d3262963278d6384692de);
#
#
#             var icon_b8a765fcd73af419028f5a477310387e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_37108b1003e7b2f7609b7e7f464cbe8f.setIcon(icon_b8a765fcd73af419028f5a477310387e);
#
#
#             var marker_debff16e8096e08f1c8663fce0233ac6 = L.marker(
#                 [37.20416666666667, 128.85166666666666],
#                 {}
#             ).addTo(marker_cluster_16eb280ac26d3262963278d6384692de);
#
#
#             var icon_86a97747aba6d945e0c6670f3d921eaf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_debff16e8096e08f1c8663fce0233ac6.setIcon(icon_86a97747aba6d945e0c6670f3d921eaf);
#
#
#             var marker_06c34473391c892001601c8b1d6691e6 = L.marker(
#                 [37.365833333333335, 128.9972222222222],
#                 {}
#             ).addTo(marker_cluster_16eb280ac26d3262963278d6384692de);
#
#
#             var icon_1fe2b2ed8d963453d0aa556942216ac6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_06c34473391c892001601c8b1d6691e6.setIcon(icon_1fe2b2ed8d963453d0aa556942216ac6);
#
#
#             var marker_0143010345231273cd0bc6

# %%
from streamlit_folium import st_folium

# %%
serviceKey = 'A3A7BEB0-361E-4134-878C-BD8004204558'
HydroType = 'waterlevel'
DataType = 'list'
DocumentType = '.json'
water_level_live = flowsiteAPI_livedata(serviceKey, HydroType, DataType, DocumentType)
DataType = 'info'
water_level = pd.read_csv('C:/pythonproject/streamlit (2)/pages/using_data/flowsiteAPI_data.csv')
water_level_live['wlobscd'] = water_level_live['wlobscd'].astype('int64')
data = pd.merge(water_level, water_level_live, on = 'wlobscd', how = 'inner')
data = data[data['almwl'] != ' ']
data[['attwl', 'wrnwl', 'almwl', 'srswl', 'wl']] = data[['attwl', 'wrnwl', 'almwl', 'srswl', 'wl']].astype('float64')
data['수위경보'] = data.apply(lambda x : '심각 수위 단계' if x['wl'] >= x['srswl']
                                                    else ('경보수위 단계' if x['wl'] >= x['almwl']
                                                    else ('주의보수위 단계' if x['wl'] >= x['wrnwl']
                                                    else ('관심수위 단계' if x['wl'] >= x['attwl'] else '정상수위 단계')))  , axis = 1)
data
# Out:
#      wlobscd agcnm       obsnm          addr          etcaddr         lon  \
# 0    1001602   환경부    평창군(송정교)   강원도 평창군 진부면         하진부리 송정교  128.551111
# 1    1001620   환경부    정선군(송계교)       강원도 정선군      임계면 봉산리 송계교  128.849167
# 2    1001622   환경부    정선군(혈천교)       강원도 정선군      임계면 낙천리 혈천교  128.846944
# 3    1001625   환경부    정선군(송천교)       강원도 정선군      여량면 유천리 송천교  128.718611
# 4    1001626   환경부  정선군(제1여량교)   강원도 정선군 여량면        여량리 제1여량교  128.729167
# ..       ...   ...         ...           ...              ...         ...
# 425  3101690   환경부    아산시(강청교)      충청남도 아산시      염치면 가덕리 강청교  126.933611
# 426  3101693   환경부    당진시(신촌리)      충청남도 당진군  우강면 신촌리 107-119  126.827500
# 427  3101696   환경부    당진시(북창교)  충청남도 당진군 순성면        중방리 150-4  126.761389
# 428  3201690   환경부    당진시(채운교)      충청남도 당진군      당진시 우두동 채운교  126.614444
# 429  5001615   환경부    담양군(금월교)      전라남도 담양군   담양읍 학동리 금월교 하류  127.016667
#
#            lat      gdt  attwl  wrnwl  ...  srswl   pfh fstnyn links_x   시도명  \
# 0    37.624167  511.589    8.5    9.5  ...   14.9  14.9      N      []   강원도
# 1    37.494167  491.020    1.5    2.5  ...    3.6  3.64      N      []   강원도
# 2    37.464722  479.382    3.0    4.0  ...    6.6  6.64      N      []   강원도
# 3    37.485556  374.685    3.5    4.5  ...    7.3  7.32      N      []   강원도
# 4    37.473333  369.492    4.0    5.0  ...    7.8  7.78      N      []   강원도
# ..         ...      ...    ...    ...  ...    ...   ...    ...     ...   ...
# 425  36.821667    1.136    3.5    3.9  ...    6.0  7.21      N      []  충청남도
# 426  36.847778   -1.245    4.3    4.8  ...    6.6  5.38      N      []  충청남도
# 427  36.852222    1.018    3.5    4.5  ...    6.5            N      []  충청남도
# 428  36.905000    1.192    2.5    4.0  ...    6.2   7.4      N      []  충청남도
# 429  35.332778   53.590    1.5    2.0  ...    3.0  3.65      N      []  전라남도
#
#             ymdhm    wl     fw links_y     수위경보
# 0    202212170650  1.40             []  정상수위 단계
# 1    202212170650 -0.36   0.08      []  정상수위 단계
# 2    202212170650  1.18   1.15      []  정상수위 단계
# 3    202212170650  0.65   1.78      []  정상수위 단계
# 4    202212170650  1.47   2.85      []  정상수위 단계
# ..            ...   ...    ...     ...      ...
# 425  202212170650  0.67  33.29      []  정상수위 단계
# 426  202212170650  3.04             []  정상수위 단계
# 427  202212170650  1.40             []  정상수위 단계
# 428  202212170650  0.99  97.99      []  정상수위 단계
# 429  202212170650  0.16   0.10      []  정상수위 단계
#
# [429 rows x 21 columns]

# %%
serviceKey = 'A3A7BEB0-361E-4134-878C-BD8004204558'
HydroType = 'waterlevel'
DataType = 'list'
DocumentType = '.json'
water_level_live = flowsiteAPI_livedata(serviceKey, HydroType, DataType, DocumentType)
DataType = 'info'

data = pd.merge(water_level, water_level_live, on = 'wlobscd', how = 'inner')
data = data[data['almwl'] != ' ']
data[['attwl', 'wrnwl', 'almwl', 'srswl', 'wl']] = data[['attwl', 'wrnwl', 'almwl', 'srswl', 'wl']].astype('float64')
data['수위경보'] = data.apply(lambda x : '심각 수위 단계' if x['wl'] >= x['srswl']
                                                    else ('경보수위 단계' if x['wl'] >= x['almwl']
                                                    else ('주의보수위 단계' if x['wl'] >= x['wrnwl']
                                                    else ('관심수위 단계' if x['wl'] >= x['attwl'] else '정상수위 단계')))  , axis = 1)

# %%
water_level = flowsiteAPI_data(serviceKey, HydroType, DataType, DocumentType)
# water_level = water_level[water_level['attwl'] != ' ']
# water_level['시도명'] = water_level['addr'].str.split(' ').str[0]
water_level['lat'] = water_level['lat'].apply(lambda x : int(x.split('-')[0]) + (int(x.split('-')[1]) / 60) + (int(x.split('-')[2]) / 3600) if len(x.split('-')) == 3 else x)
water_level['lon'] = water_level['lon'].apply(lambda x : int(x.split('-')[0]) + (int(x.split('-')[1]) / 60) + (int(x.split('-')[2]) / 3600) if len(x.split('-')) == 3 else x)

# %%
water_level = water_level[(water_level['lon'] != ' ') & (water_level['lat'] != ' ')]
water_level['lat'] = water_level['lat'].apply(lambda x : int(x.split('-')[0]) + (int(x.split('-')[1]) / 60) + (int(x.split('-')[2]) / 3600) if len(x.split('-')) == 3 else x)
water_level['lon'] = water_level['lon'].apply(lambda x : int(x.split('-')[0]) + (int(x.split('-')[1]) / 60) + (int(x.split('-')[2]) / 3600) if len(x.split('-')) == 3 else x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\pythonproject\streamlit (2)\appreciate.ipynb Cell 33 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/pythonproject/streamlit%20%282%29/appreciate.ipynb#X44sZmlsZQ%3D%3D?line=0'>1</a> water_level = water_level[(water_level['lon'] != ' ') & (water_level['lat'] != ' ')]
# ----> <a href='vscode-notebook-cell:/c%3A/pythonproject/streamlit%20%282%29/appreciate.ipynb#X44sZmlsZQ%3D%3D?line=1'>2</a> water_level['lat'] = water_level['lat'].apply(lambda x : int(x.split('-')[0]) + (int(x.split('-')[1]) / 60) + (int(x.split('-')[2]) / 3600) if len(x.split('-')) == 3 else x)
#       <a href='vscode-notebook-cell:/c%3A/pythonproject/streamlit%20%282%29/appreciate.ipynb#X44sZmlsZQ%3D%3D?line=2'>3</a> water_level['lon'] = water_level['lon'].apply(lambda x : int(x.split('-')[0]) + (int(x.split('-')[1]) / 60) + (int(x.split('-')[2]) / 3600) if len(x.split('-')) == 3 else x)
#
# File c:\Users\wjddm\anaconda3\envs\sangwook\lib\site-packages\pandas\core\series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File c:\Users\wjddm\anaconda3\envs\sangwook\lib\site-packages\pandas\core\apply.py:1088, in SeriesApply.apply(self)
#    1084 if isinstance(self.f, str):
#    1085     # if we are a string, try to dispatch
#    1086     return self.apply_str()
# -> 1088 return self.apply_standard()
#
# File c:\Users\wjddm\anaconda3\envs\sangwook\lib\site-packages\pandas\core\apply.py:1143, in SeriesApply.apply_standard(self)
#    1137         values = obj.astype(object)._values
#    1138         # error: Argument 2 to "map_infer" has incompatible type
#    1139         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1140         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1141         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1142         # "Callable[[Any], Any]"
# -> 1143         mapped = lib.map_infer(
#    1144             values,
#    1145             f,  # type: ignore[arg-type]
#    1146             convert=self.convert_dtype,
#    1147         )
#    1149 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1150     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1151     #  See also GH#25959 regarding EA support
#    1152     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\wjddm\anaconda3\envs\sangwook\lib\site-packages\pandas\_libs\lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# c:\pythonproject\streamlit (2)\appreciate.ipynb Cell 33 in <lambda>(x)
#       <a href='vscode-notebook-cell:/c%3A/pythonproject/streamlit%20%282%29/appreciate.ipynb#X44sZmlsZQ%3D%3D?line=0'>1</a> water_level = water_level[(water_level['lon'] != ' ') & (water_level['lat'] != ' ')]
# ----> <a href='vscode-notebook-cell:/c%3A/pythonproject/streamlit%20%282%29/appreciate.ipynb#X44sZmlsZQ%3D%3D?line=1'>2</a> water_level['lat'] = water_level['lat'].apply(lambda x : int(x.split('-')[0]) + (int(x.split('-')[1]) / 60) + (int(x.split('-')[2]) / 3600) if len(x.split('-')) == 3 else x)
#       <a href='vscode-notebook-cell:/c%3A/pythonproject/streamlit%20%282%29/appreciate.ipynb#X44sZmlsZQ%3D%3D?line=2'>3</a> water_level['lon'] = water_level['lon'].apply(lambda x : int(x.split('-')[0]) + (int(x.split('-')[1]) / 60) + (int(x.split('-')[2]) / 3600) if len(x.split('-')) == 3 else x)
#
# ValueError: invalid literal for int() with base 10: ' '

# %%
water_level = water_level[(water_level['lon'] != ' ') & (water_level['lat'] != ' ')]

# %%
water_level
# Out:
#       wlobscd    agcnm        obsnm              addr       etcaddr  \
# 0     1001602      환경부     평창군(송정교)       강원도 평창군 진부면      하진부리 송정교
# 1     1001603  한국수자원공사     태백시(무사교)      강원도 태백시 상사미동
# 2     1001605  한국수력원자력         송천1교           강원도 평창군      대관령면 횡계리
# 3     1001607  한국수자원공사     삼척시(번천교)       강원도 삼척시 하장면      번천리 천375
# 4     1001610  한국수자원공사     삼척시(광동댐)           강원도 삼척시  하장면 숙암리 산104
# ...       ...      ...          ...               ...           ...
# 1015  5302660      환경부     영광군(외간교)          전라남도 영광군       군남면 동간리
# 1016  6001650      환경부    제주시(개롱이교)   제주특별자치도 제주시 애월읍           금성리
# 1017  6002670      환경부   제주시(제2동산교)  제주특별자치도 제주시 오라일동
# 1018  6003620      환경부  서귀포시(개끄리민교)  제주특별자치도 서귀포시 안덕면           감산리
# 1019  6004670      환경부    서귀포시(평화교)  제주특별자치도 서귀포시 성산읍           신천리
#
#             lon        lat      gdt attwl wrnwl almwl srswl   pfh fstnyn links
# 0     128-33-04  37-37-27   511.589   8.5   9.5    12  14.9  14.9      N    []
# 1     128-59-40  37-18-54   687.824                                    N    []
# 2     128-42-35  37-40-05   724.782                                    N    []
# 3     128-59-47  37-21-52   718.848                                    N    []
# 4     128-56-50  37-20-37                                              N    []
# ...         ...        ...      ...   ...   ...   ...   ...   ...    ...   ...
# 1015  126-27-58  35-14-56      3.37                          5.77      N    []
# 1016  126-18-03  33-26-12    16.685                                    N    []
# 1017  126-30-43  33-29-45    51.845                                    N    []
# 1018  126-20-31  33-14-38     5.132                                    N    []
# 1019  126-50-48  33-20-33    13.477                                    N    []
#
# [1014 rows x 15 columns]

# %%
def rainfall_api():
    serviceKey = 'A3A7BEB0-361E-4134-878C-BD8004204558'
    HydroType = 'rainfall'
    DataType = 'list'
    DocumentType = '.json'
    water_level_live = flowsiteAPI_livedata(serviceKey, HydroType, DataType, DocumentType)
    DataType = 'info'
    water_level = flowsiteAPI_data(serviceKey, HydroType, DataType, DocumentType)
    water_level['시도명'] = water_level['addr'].str.split(' ').str[0]
    water_level['lat'] = water_level['lat'].apply(lambda x : int(x.split('-')[0]) + (int(x.split('-')[1]) / 60) + (int(x.split('-')[2]) / 3600) if len(x.split('-')) == 3 else x)
    water_level['lon'] = water_level['lon'].apply(lambda x : int(x.split('-')[0]) + (int(x.split('-')[1]) / 60) + (int(x.split('-')[2]) / 3600) if len(x.split('-')) == 3 else x)
    rainfall_df = pd.merge(water_level, water_level_live, on = 'rfobscd', how = 'inner')
    return rainfall_df

df = rainfall_api()

# %%
import folium
def rainfall_map(data):
    m = folium.Map(
    location=[data['lat'].mean(), data['lon'].mean()],
    zoom_start= 7
    )
    coords = data[['lat', 'lon', 'obsnm', 'rf']]
    for idx in coords.index:
        folium.Marker([coords.loc[idx, 'lat'], coords.loc[idx, 'lon']], icon = folium.Icon(color="green"), tooltip = coords.loc[idx,'obsnm'] + ' : ' + str(coords.loc[idx,'rf'])).add_to(m)
    return m
rainfall_map(df)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_efe8fc11264b0e97d806f16a3f31c065 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_efe8fc11264b0e97d806f16a3f31c065&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_efe8fc11264b0e97d806f16a3f31c065 = L.map(
#                 &quot;map_efe8fc11264b0e97d806f16a3f31c065&quot;,
#                 {
#                     center: [36.47402756042424, 127.8888593288125],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fc800c43d9575933154d2699db0da3bc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_efe8fc11264b0e97d806f16a3f31c065);
#
#
#             var marker_fb64344b9a7132f4bfaf6e94847391bb = L.marker(
#                 [37.70944444444445, 128.5991666666667],
#                 {}
#             ).addTo(map_efe8fc11264b0e97d806f16a3f31c065);
#
#
#             var icon_766a1cbed12898a8481b40eb5c546445 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fb64344b9a7132f4bfaf6e94847391bb.setIcon(icon_766a1cbed12898a8481b40eb5c546445);
#
#
#             marker_fb64344b9a7132f4bfaf6e94847391bb.bindTooltip(
#                 `&lt;div&gt;
#                      평창군(월정분교) : 0.0
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7dd00caf2efc13f1d6cb72b428af41ae = L.marker(
#                 [37.384166666666665, 128.67361111111111],
#                 {}
#             ).addTo(map_efe8fc11264b0e97d806f16a3f31c065);
#
#
#             var icon_5cc8f9343ab60f1e047ca2d689b9c36c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7dd00caf2efc13f1d6cb72b428af41ae.setIcon(icon_5cc8f9343ab60f1e047ca2d689b9c36c);
#
#
#             marker_7dd00caf2efc13f1d6cb72b428af41ae.bindTooltip(
#                 `&lt;div&gt;
#                      정선군(정선군2청사) : 0.0
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_fb1a9b3b4cfcfeee50d669558a13a24e = L.marker(
#                 [37.586111111111116, 128.7775],
#                 {}
#             ).addTo(map_efe8fc11264b0e97d806f16a3f31c065);
#
#
#             var icon_bf2eec11c02fe3f2fcae5e64a71b4695 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fb1a9b3b4cfcfeee50d669558a13a24e.setIcon(icon_bf2eec11c02fe3f2fcae5e64a71b4695);
#
#
#             marker_fb1a9b3b4cfcfeee50d669558a13a24e.bindTooltip(
#                 `&lt;div&gt;
#                      강릉시(대기리) : 0.0
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_82109073042333e8cd1483846fdae0d8 = L.marker(
#                 [37.20416666666667, 128.85166666666666],
#                 {}
#             ).addTo(map_efe8fc11264b0e97d806f16a3f31c065);
#
#
#             var icon_109180650bdb2119974279130f0de62f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_82109073042333e8cd1483846fdae0d8.setIcon(icon_109180650bdb2119974279130f0de62f);
#
#
#             marker_82109073042333e8cd1483846fdae0d8.bindTooltip(
#                 `&lt;div&gt;
#                      정선군(고한읍사무소) : 0.0
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_76f266001aed13c8cc8d16b30f2f6b04 = L.marker(
#                 [37.365833333333335, 128.9972222222222],
#                 {}
#             ).addTo(map_efe8fc11264b0e97d806f16a3f31c065);
#
#
#             var icon_183197ad206682471195c57c71470fa4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green

# %%
from datetime import datetime
def flood_news(serviceKey, HydroType, DataType,Edt, DocumentType):
        url = f'https://api.hrfco.go.kr/{serviceKey}/{HydroType}/{DataType}/{Edt}{DocumentType}'
        response = requests.get(url)
        contents = response.text
        json_ob = json.loads(contents)
        body = json_ob['content']
        body = pd.json_normalize(body)
        return body
    
serviceKey = 'A3A7BEB0-361E-4134-878C-BD8004204558'
HydroType = 'fldfct'
DataType = 'list'
Edt = '20220906'
DocumnetType = '.json'
print(datetime.today().strftime(("%Y%m%d")))
df = flood_news(serviceKey, HydroType, DataType, Edt, DocumentType).drop(columns = 'links')
df.columns = ['발표일시','발표자','수위도달 예상일시', '예상 수위표수위', '예상 해발수위', '홍수예보 종류', '홍수예보 번호', '지점', '기존발령일시', 
            '비고','강명','변동상황', '현재 일시', '현재 수위표수위', '현재 해발수위', '예상 일시(변동)', '예상 수위표수위(변동)', '예상 해발수위(변동)', '관측소 코드', '주의 지역', 
            '주의 강명']
# Out:
# 20221217

# %%
list_ = []
for idx in df.index:
    if df.loc[idx,'홍수예보 종류'][-2:] == '발령':
        list_.append(df.loc[idx, '주의 지역'])
list_
# Out:
# ['밀양, 청도', '경주', '포항', '울산', '포항', '경주', '함양, 산청', '홍천', '포천, 연천']

# %%
import requests
import pprint
import json
import pandas as pd

def damAPI_data(serviceKey, HydroType, DataType, DocumentType):
        url = f'https://api.hrfco.go.kr/{serviceKey}/{HydroType}/{DataType}{DocumentType}'
        response = requests.get(url)
        contents = response.text
        json_ob = json.loads(contents)
        body = json_ob['content']
        body = pd.json_normalize(body)
        return body

def dam_livedata(serviceKey, HydroType, DataType, DocumentType):
        url = f'https://api.hrfco.go.kr/{serviceKey}/{HydroType}/{DataType}/1H{DocumentType}'
        response = requests.get(url)
        contents = response.text
        pp = pprint.PrettyPrinter(indent =4)
        # pp.pprint(response.content)
        json_ob = json.loads(contents)
        body = json_ob['content']
        # body = json_ob['response']['body']['item']
        body = pd.json_normalize(body)
        return body

def dam_data_make():
        serviceKey = 'A3A7BEB0-361E-4134-878C-BD8004204558'
        HydroType = 'dam'
        DataType = 'list'
        DocumnetType = '.json'
        livedata = flowsiteAPI_livedata(serviceKey, HydroType, DataType, DocumentType)
        DataType = 'info'
        data = flowsiteAPI_data(serviceKey, HydroType, DataType, DocumentType)
        dam_data = pd.merge(data, livedata, on = 'dmobscd', how = 'inner')
        dam_data = dam_data[dam_data['lat'] != ' ']
        dam_data = dam_data[dam_data['lon'] != ' ']
        dam_data['lat'] = dam_data['lat'].apply(lambda x : int(x.split('-')[0]) + (int(x.split('-')[1]) / 60) + (int(x.split('-')[2]) / 3600) if len(x.split('-')) == 3 else x)
        dam_data['lon'] = dam_data['lon'].apply(lambda x : int(x.split('-')[0]) + (int(x.split('-')[1]) / 60) + (int(x.split('-')[2]) / 3600) if len(x.split('-')) == 3 else x)
        return dam_data

def dam_map(data):
        m = folium.Map(
        location=[data['lat'].mean(), data['lon'].mean()],
        zoom_start= 7
        )
        coords = data[['lat', 'lon', 'obsnm', 'swl', 'inf', 'sfw', 'ecpc', 'tototf']]
        for idx in coords.index:
                text = coords.loc[idx,'obsnm']+ '<br>현재 수위 :' + str(coords.loc[idx,'swl']) + '<br>유입량 :' + str(coords.loc[idx,'inf'])+ '<br>저수량 :' + str(coords.loc[idx,'sfw']) + '<br>공용량 :' + str(coords.loc[idx,'ecpc']) + '<br>총 방류량 :' + str(coords.loc[idx,'tototf'])
                folium.Marker([coords.loc[idx, 'lat'], coords.loc[idx, 'lon']], icon = folium.Icon(color="purple"), tooltip = text).add_to(m)
        return m

# %%
import requests
import pprint
import json
import pandas as pd

def bo_data_make():
        serviceKey = 'A3A7BEB0-361E-4134-878C-BD8004204558'
        HydroType = 'bo'
        DataType = 'list'
        DocumnetType = '.json'
        livedata = flowsiteAPI_livedata(serviceKey, HydroType, DataType, DocumentType)
        DataType = 'info'
        data = flowsiteAPI_data(serviceKey, HydroType, DataType, DocumentType)
        bo_data = pd.merge(data, livedata, on = 'boobscd', how = 'inner')
        bo_data = bo_data[bo_data['lat'] != ' ']
        bo_data = bo_data[bo_data['lon'] != ' ']
        bo_data['lat'] = bo_data['lat'].apply(lambda x : int(x.split('-')[0]) + (int(x.split('-')[1]) / 60) + (int(x.split('-')[2]) / 3600) if len(x.split('-')) == 3 else x)
        bo_data['lon'] = bo_data['lon'].apply(lambda x : int(x.split('-')[0]) + (int(x.split('-')[1]) / 60) + (int(x.split('-')[2]) / 3600) if len(x.split('-')) == 3 else x)
        return bo_data

def bo_map(data):
        m = folium.Map(
        location=[data['lat'].mean(), data['lon'].mean()],
        zoom_start= 7
        )
        coords = data[['lat', 'lon', 'obsnm', 'swl', 'inf', 'sfw', 'ecpc', 'tototf']]
        for idx in coords.index:
                text = coords.loc[idx,'obsnm']+ '<br>현재 수위 :' + str(coords.loc[idx,'swl']) + '<br>유입량 :' + str(coords.loc[idx,'inf'])+ '<br>저수량 :' + str(coords.loc[idx,'sfw']) + '<br>공용량 :' + str(coords.loc[idx,'ecpc']) + '<br>총 방류량 :' + str(coords.loc[idx,'tototf'])
                folium.Marker([coords.loc[idx, 'lat'], coords.loc[idx, 'lon']], icon = folium.Icon(color="purple"), tooltip = text).add_to(m)
        return m

# %%
data = bo_data_make()
bo_map(data)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b483b02f55b3111a17035e40dd66f151 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b483b02f55b3111a17035e40dd66f151&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b483b02f55b3111a17035e40dd66f151 = L.map(
#                 &quot;map_b483b02f55b3111a17035e40dd66f151&quot;,
#                 {
#                     center: [35.857083333333335, 127.91063492063493],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_158f8689f84e53949b81e8b04b1835fc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b483b02f55b3111a17035e40dd66f151);
#
#
#             var marker_863b0782494d76342ce29d137b0b6487 = L.marker(
#                 [36.433055555555555, 128.24888888888887],
#                 {}
#             ).addTo(map_b483b02f55b3111a17035e40dd66f151);
#
#
#             var icon_0553bb278c5e411500398b2342185e0e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_863b0782494d76342ce29d137b0b6487.setIcon(icon_0553bb278c5e411500398b2342185e0e);
#
#
#             marker_863b0782494d76342ce29d137b0b6487.bindTooltip(
#                 `&lt;div&gt;
#                      상주보&lt;br&gt;현재 수위 :47.120&lt;br&gt;유입량 :37.109&lt;br&gt;저수량 :27.907&lt;br&gt;공용량 :0.000&lt;br&gt;총 방류량 :37.081
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3357092adf616cb20a35e6b7e741d2ce = L.marker(
#                 [36.36, 128.30583333333334],
#                 {}
#             ).addTo(map_b483b02f55b3111a17035e40dd66f151);
#
#
#             var icon_e6c4b789dfa2746a9893b983a1123723 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3357092adf616cb20a35e6b7e741d2ce.setIcon(icon_e6c4b789dfa2746a9893b983a1123723);
#
#
#             marker_3357092adf616cb20a35e6b7e741d2ce.bindTooltip(
#                 `&lt;div&gt;
#                      낙단보&lt;br&gt;현재 수위 :39.770&lt;br&gt;유입량 :23.317&lt;br&gt;저수량 :33.328&lt;br&gt;공용량 :1.349&lt;br&gt;총 방류량 :23.317
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_98f85325ea42974c159d208750925f34 = L.marker(
#                 [36.23694444444445, 128.34555555555556],
#                 {}
#             ).addTo(map_b483b02f55b3111a17035e40dd66f151);
#
#
#             var icon_8dabb91dcb7304b8237656337c884d98 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_98f85325ea42974c159d208750925f34.setIcon(icon_8dabb91dcb7304b8237656337c884d98);
#
#
#             marker_98f85325ea42974c159d208750925f34.bindTooltip(
#                 `&lt;div&gt;
#                      구미보&lt;br&gt;현재 수위 :30.560&lt;br&gt;유입량 :59.500&lt;br&gt;저수량 :38.688&lt;br&gt;공용량 :14.045&lt;br&gt;총 방류량 :59.500
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_890e31d012fc3b2362c751948b94ae4e = L.marker(
#                 [36.01555555555556, 128.39805555555554],
#                 {}
#             ).addTo(map_b483b02f55b3111a17035e40dd66f151);
#
#
#             var icon_87447ac45e79f6bc4690c3a4c7c90368 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_890e31d012fc3b2362c751948b94ae4e.setIcon(icon_87447ac45e79f6bc4690c3a4c7c90368);
#
#
#             marker_890e31d012fc3b2362c751948b94ae4e.bindTooltip(
#                 `&lt;div&gt;
#                      칠곡보&lt;br&gt;현재 수위 :24.590&lt;br&gt;유입량 :60.856&lt;br&gt;저수량 :63.083&lt;br&gt;공용량 :12.232&lt;br&gt;총 방류량 :60.848
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ccb464cf56eceeb81fb3038ed90057f6 = L.marker(
#                 [35.84, 128.
